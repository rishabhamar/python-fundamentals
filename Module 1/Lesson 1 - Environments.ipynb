# %% [markdown]
# ## Creating Python Environment using Conda

# %%
conda create -p venv python==3.12 -y
conda activate venv/

# %% [markdown]
# ## Creating Python Environment using Venv

# %%
python -m venv myenv
myenv\Scripts\activate

# %% [markdown]
# ## Creating Python Environment using VirtualEnv

# %%
virtualenv -p python3 virtual_env
virtual_env\Scripts\activate

# %% [markdown]
# ## Creating Python Environment in Linux using VirtualEnv

# %%
sudo apt-get install python3-pipsudo apt install python3-virtualenvvirtualenv virtualenv_namesource virtualenv_name/bin/activate
